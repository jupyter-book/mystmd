# %% [markdown]
# # An Example Notebook
#
# For CI smoke testing

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
N = np.random.random((8,8))

# %%
plt.figure(figsize=(10,10))
plt.imshow(N);
